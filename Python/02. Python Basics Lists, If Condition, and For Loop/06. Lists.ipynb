# %%
items = ['bread','pasta','fruits','veggies']

# %%
items[0]
# Out:
# 'bread'

# %%
items[0:2]
# Out:
# ['bread', 'pasta']

# %%
items.append('butter')

# %%
items
# Out:
# ['bread', 'pasta', 'fruits', 'veggies', 'butter']

# %%
items.remove('butter')

# %%
items
# Out:
# ['bread', 'pasta', 'fruits', 'veggies']

# %%
items.insert(1,'butter')

# %%
items
# Out:
# ['bread', 'butter', 'pasta', 'fruits', 'veggies']

# %%
items[1] = 'cheese'

# %%
items
# Out:
# ['bread', 'cheese', 'pasta', 'fruits', 'veggies']

# %%
items[3:] = ['almonds']

# %%
items
# Out:
# ['bread', 'cheese', 'pasta', 'almonds']

# %%
'rice' in items
# Out:
# False

# %%
'bread' in items
# Out:
# True

# %%
expenses = [300,200,1200,700]
expenses.sort()
expenses
# Out:
# [200, 300, 700, 1200]

# %%
food_items = ['bread','pasta','fruit']
bath_items = ['shampoo','soap']

# %%
all_items = food_items + bath_items
all_items
# Out:
# ['bread', 'pasta', 'fruit', 'shampoo', 'soap']

# %%
len(all_items)
# Out:
# 5

# %%
dir(all_items)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
random = ['bread',4.6,True]
random
# Out:
# ['bread', 4.6, True]
