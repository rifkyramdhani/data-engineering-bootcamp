# %% [markdown]
# Learning Strings

# %%
first = 'Rifky'
last = 'Ramdhani'

# %%
fullname = first + ' ' + last
fullname
# Out:
# 'Rifky Ramdhani'

# %%
fullname2 = f"{first} {last}"
fullname2
# Out:
# 'Rifky Ramdhani'

# %%
age = 27

# %%
info = f"{first} {last} is {age} years old"
info
# Out:
# 'Rifky Ramdhani is 27 years old'

# %%
fullname2[0]
# Out:
# 'R'

# %%
fullname2[0:5]
# Out:
# 'Rifky'

# %%
fullname2[6:14]
# Out:
# 'Ramdhani'

# %%
fullname2[6:]
# Out:
# 'Ramdhani'

# %%
fullname2[-1]
# Out:
# 'i'

# %%
len(fullname2)
# Out:
# 14

# %%
test = "Rifky's favourite fruit is mango"
test2 = 'he said "Hello"'

# %%
test
# Out:
# "Rifky's favourite fruit is mango"

# %%
test2
# Out:
# 'he said "Hello"'

# %%
paragraph = '''
adasd
asdaff
aweqawe
test
wqerqwe
qweqwe
'''

# %%
paragraph
# Out:
# '\nadasd\nasdaff\naweqawe\ntest\nwqerqwe\nqweqwe\n'

# %%
print(paragraph)
# Out:
# adasd
# asdaff
# aweqawe
# test
# wqerqwe
# qweqwe

# %%
x = 'test'

# %%
x in paragraph
# Out:
# True

# %%
'test' in paragraph
# Out:
# True

# %%
paragraph.find(x)
# Out:
# 22

# %%
s = 'the price is $100'

# %%
s.replace('100','99')
# Out:
# 'the price is $99'

# %%
s
# Out:
# 'the price is $100'

# %%
s = s.replace('100','99')

# %%
s
# Out:
# 'the price is $99'

# %%
s.upper()
# Out:
# 'THE PRICE IS $99'

# %%
a = 'ABC'
a.lower()
# Out:
# 'abc'

# %%
'444'.isdigit()
# Out:
# True

# %%
'33re'.isdigit()
# Out:
# False

# %%
s.index('$99')
# Out:
# 13

# %%
text = 'my age is'
age = 27

# %%
text2 = f"{text} {age}"

# %%
text2
# Out:
# 'my age is 27'

# %%
s = 'hey\tbro'

# %%
s
# Out:
# 'hey\tbro'

# %%
print(s)
# Out:
# hey	bro

# %%
tickers = 'AAA|BBB|CCC|DDD'

# %%
tickers.split('|')
# Out:
# ['AAA', 'BBB', 'CCC', 'DDD']

# %%
tickers.split('|',2)
# Out:
# ['AAA', 'BBB', 'CCC|DDD']

# %%
text = '    how are you?   '

# %%
text
# Out:
# '    how are you?   '

# %%
text.strip()
# Out:
# 'how are you?'

# %%
file_name = 'test.pdf'

# %%
file_name.endswith('.pdf')
# Out:
# True
