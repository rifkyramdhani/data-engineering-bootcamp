# %% [markdown]
# Learning About Variables

# %%
can='milk'

# %%
print(can)
# Out:
# milk

# %%
type(can)
# Out:
# str

# %%
pizza = 100.5
bread = 50
cake = 100

# %%
total = pizza + bread + cake

# %%
print(total)
# Out:
# 250.5

# %%
type(total)
# Out:
# float

# %%
threshold_money = total > 200

# %%
threshold_money
# Out:
# True

# %%
type(threshold_money)
# Out:
# bool
