# %%
import math

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
pip install numpy
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install --upgrade pip
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.8 MB 399.6 kB/s eta 0:00:04
#    ----------------- ---------------------- 0.8/1.8 MB 568.6 kB/s eta 0:00:02
#    ----------------------- ---------------- 1.0/1.8 MB 653.7 kB/s eta 0:00:02
#    ----------------------- ---------------- 1.0/1.8 MB 653.7 kB/s eta 0:00:02
#    ----------------------------- ---------- 1.3/1.8 MB 692.1 kB/s eta 0:00:01
#    ----------------------------------- ---- 1.6/1.8 MB 729.4 kB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 764.4 kB/s eta 0:00:00
# ...

# %%
import numpy as np

# %%
# Sales data for Quarter 1 (Matrix 1)
# Rows represent different products, columns represent different regions

q1 = np.array([
    [200,210,190],  # product 1
    [180,195,200],  # product 2
    [185,190,195]   # product 3
])


q2 = np.array([
    [205,215,195],  # product 1
    [185,300,205],  # product 2
    [190,195,300]   # product 3
])

# %%
q1 + q2
# Out:
# array([[405, 425, 385],
#        [365, 495, 405],
#        [375, 385, 495]])

# %%
growth = q2 - q1
growth
# Out:
# array([[  5,   5,   5],
#        [  5, 105,   5],
#        [  5,   5, 105]])
