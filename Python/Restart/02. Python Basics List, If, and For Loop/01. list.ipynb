# %%
list = ['bread','milk','pasta','fruits']

# %%
list[0:2]
# Out:
# ['bread', 'milk']

# %%
list.append('veggies')

# %%
list
# Out:
# ['bread', 'milk', 'pasta', 'fruits', 'veggies']

# %%
list.remove('bread')
list
# Out:
# ['milk', 'pasta', 'fruits', 'veggies']

# %%
list.insert(1,'bread')
list
# Out:
# ['milk', 'bread', 'pasta', 'fruits', 'veggies']

# %%
list[0] = 'water'
list
# Out:
# ['water', 'bread', 'pasta', 'fruits', 'veggies']

# %%
'water' in list
# Out:
# True

# %%
num = [100,200,500,150,250]
num.sort()
num
# Out:
# [100, 150, 200, 250, 500]
