# %%
can = 'soda'

# %%
can
# Out:
# 'soda'

# %%
print(can)
# Out:
# soda

# %%
type(can)
# Out:
# str

# %%
pizza = 100
samosa = 20.5
ice_cream = 100

# %%
total = pizza + samosa + ice_cream
total
# Out:
# 220.5

# %%
type(total)
# Out:
# float

# %%
threshold = total > 200
threshold
# Out:
# True

# %%
food = 'rice'
food
# Out:
# 'rice'

# %%
eat = food
eat
# Out:
# 'rice'

# %%
id(food)
# Out:
# 4503526768

# %%
id(eat)
# Out:
# 4503526768

# %%
eat = 'nugget'
id(eat)
# Out:
# 4503561200
