# %%
first = 'Rifky'
last = 'Ramdhani'

# %%
full_name = first + last
full_name
# Out:
# 'RifkyRamdhani'

# %%
full_name = first + ' ' + last
full_name
# Out:
# 'Rifky Ramdhani'

# %%
full_name = f"{first} {last}"
full_name
# Out:
# 'Rifky Ramdhani'

# %%
full_name[0:5]
# Out:
# 'Rifky'

# %%
full_name[6:14]
# Out:
# 'Ramdhani'

# %%
full_name[6:]
# Out:
# 'Ramdhani'

# %%
recipe = '''
coffee, milk, brown sugar, creamer
'''

# %%
sugar = 'brown sugar'

sugar in recipe
# Out:
# True

# %%
recipe.find(sugar)
# Out:
# 15

# %%
t = 'total price is $200'

# %%
t = t.replace('$200','$50')
t
# Out:
# 'total price is $50'

# %%
t.upper()
# Out:
# 'TOTAL PRICE IS $50'

# %%
t.index('$50')
# Out:
# 15

# %%
text = 'my age is'
age = 28

# %%
f"{text} {28}"
# Out:
# 'my age is 28'

# %%
veg = 'carrot,spinach,chilli,tomato'

# %%
veg.split(',')
# Out:
# ['carrot', 'spinach', 'chilli', 'tomato']

# %%
text = '   my name is jack  '
text
# Out:
# '   my name is jack  '

# %%
text.strip()
# Out:
# 'my name is jack'

# %%
file = 'file.pdf'

# %%
file.endswith('.pdf')
# Out:
# True
