# %%
x = 1
y = 2

# %%
text = f"i eat {x} fruits and {y} vegetables"
text
# Out:
# 'i eat 1 fruits and 2 vegetables'

# %%
text = "The Himalayas are one of the youngest mountain ranges on the planet."

# %%
text[0:13]
# Out:
# 'The Himalayas'

# %%
text[38:53]
# Out:
# 'mountain ranges'

# %%
f"{text[0:13]} {text[-14:]}"
# Out:
# 'The Himalayas on the planet.'

# %%
planet = 'There are 9 planets in the solar system'

# %%
planet.replace('9','8')
# Out:
# 'There are 8 planets in the solar system'

# %%
word = "Python"
print("PyT" in word)
# Out:
# False
