# %% [markdown]
# Learning numbers

# %%
base = 10
height = 7

area = (base * height)/2

# %%
print(area)
type(area)
# Out:
# 35.0
# float

# %%
x = 10
y = 3

# %%
x+y
# Out:
# 13

# %%
x/y
# Out:
# 3.3333333333333335

# %%
x//y
# Out:
# 3

# %%
x%y
# Out:
# 1

# %%
x,y
# Out:
# (10, 3)

# %%
x**y
# Out:
# 1000

# %%
10+2*3
# Out:
# 16

# %%
(10+2)*3
# Out:
# 36

# %%
foo = 2.3e4
foo
# Out:
# 23000.0

# %%
1e4
# Out:
# 10000.0

# %%
bar=2.3e-3

# %%
bar
# Out:
# 0.0023

# %%
food = 500.435
rent = 200.546
utilities = 300.45

# %%
total = food + rent + utilities
total
# Out:
# 1001.431

# %%
round(total,2)
# Out:
# 1001.43

# %%
food = '234.67'
drinks = '202.23'

# %%
total = food + drinks
total
# Out:
# '234.67202.23'

# %%
total = float(food) + float(drinks)
total
# Out:
# 436.9

# %%
import math

# %%
x = 16

# %%
math.sqrt(x)
# Out:
# 4.0

# %%
x = 3.7

# %%
math.floor(x)
# Out:
# 3

# %%
math.ceil(x)
# Out:
# 4

# %%
math.pi
# Out:
# 3.141592653589793

# %%
dir(math)
# Out:
# ['__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fma',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
format(5, 'b')
# Out:
# '101'
